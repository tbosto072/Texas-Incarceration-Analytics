# %%
import pandas as pd

# %%
df = pd.read_csv("Texas-Incarceration-Dataset.csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141173 entries, 0 to 141172
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   SID Number               141173 non-null  int64
#  1   TDCJ Number              141173 non-null  int64
#  2   Name                     141173 non-null  object
#  3   Current Facility         141173 non-null  object
#  4   Gender                   141173 non-null  object
#  5   Race                     141173 non-null  object
#  6   Age                      141173 non-null  int64
#  7   Projected Release        141172 non-null  object
#  8   Maximum Sentence Date    140802 non-null  object
#  9   Parole Eligibility Date  129187 non-null  object
#  10  Case Number              141116 non-null  object
#  11  County                   141173 non-null  object
#  12  Offense Code             141173 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# SID Number                     0
# TDCJ Number                    0
# Name                           0
# Current Facility               0
# Gender                         0
# Race                           0
# Age                            0
# Projected Release              1
# Maximum Sentence Date        371
# Parole Eligibility Date    11986
# Case Number                   57
# County                         0
# Offense Code                   0
# TDCJ Offense                  57
# Sentence Date               2673
# Offense Date                   0
# Sentence (Years)              57
# Last Parole Decision       68901
# Next Parole Review Date    30412
# Parole Review Status       12249
# dtype: int64

# %%
df["Race"].value_counts()
# Out:
# Race
# H    47973
# W    46508
# B    45884
# A      680
# I       67
# O       54
# U        7
# Name: count, dtype: int64

# %%
df["County"].value_counts()
# Out:
# County
# Harris     19529
# Dallas     13026
# Tarrant     9896
# Bexar       9057
# Smith       3245
#            ...
# Kent           3
# Terrell        3
# King           2
# Oldham         2
# Loving         1
# Name: count, Length: 254, dtype: int64

# %%
df.hist(column="Age")
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)
